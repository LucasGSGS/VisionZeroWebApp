# %% [markdown]
# ### Backend for Vision Zero Code ###
# by Richard Sowers and Lucas Gong
#
# * <r-sowers@illinois.edu>
# * <shuog2@illinois.edu>
#
# <https://publish.illinois.edu/r-sowers/>
#
# Copyright 2018 University of Illinois Board of Trustees. All Rights Reserved. Licensed under the MIT license

# %% [markdown]
# ### imports ###

# %%
import osmnx
import networkx
import pandas
import numpy
import time
import itertools
import pytz
# Out:
# WARNING:Fiona:GDAL data files not located, GDAL_DATA not set
# WARNING:Fiona:PROJ data files not located, PROJ_LIB not set

# %% [markdown]
# ### setup ###

# %%
tz="America/New_York"
region=pytz.timezone(tz)

# %% [markdown]
# ### Set up OSMNX ###

# %%
osmnx.config(log_file=True, log_console=True, use_cache=True)
G_raw = osmnx.graph_from_place('Manhattan Island, New York, USA', network_type='drive')
# Out:
# INFO:osmnx:Configured osmnx
# INFO:osmnx:Pausing 1.00 seconds before making API GET request
# INFO:osmnx:Requesting https://nominatim.openstreetmap.org/search?format=json&limit=1&dedupe=0&polygon_geojson=1&q=Manhattan+Island%2C+New+York%2C+USA with timeout=30
# INFO:osmnx:Downloaded 84.0KB from nominatim.openstreetmap.org in 0.71 seconds
# INFO:osmnx:Saved response to cache file "cache/d20b522fd82b6a936766e24673de3f23.json"
# INFO:osmnx:Created GeoDataFrame with 1 row for query "Manhattan Island, New York, USA"
# INFO:osmnx:Constructed place geometry polygon(s) to query API
# INFO:osmnx:Projected the GeoDataFrame "geometry to project" to UTM-18 in 0.01 seconds
# INFO:osmnx:Projected the GeoDataFrame "geometry to project" to EPSG 4326 in 0.00 seconds
# INFO:osmnx:Projected the GeoDataFrame "geometry to project" to UTM-18 in 0.00 seconds
# INFO:osmnx:Projected the GeoDataFrame "geometry to project" to EPSG 4326 in 0.00 seconds
# INFO:osmnx:Requesting network data within polygon from API in 1 request(s)
# INFO:osmnx:Pausing 0.00 seconds before making API POST request
# INFO:osmnx:Posting to http://www.overpass-api.de/api/interpreter with timeout=180, "{'data': '[out:json][timeout:180];(way["highway"]["area"!~"yes"]["highway"!~"cycleway|footway|path|pedestrian|steps|track|proposed|construction|bridleway|abandoned|platform|raceway|service"]["motor_vehicle"!~"no"]["motorcar"!~"no"]["access"!~"private"]["service"!~"parking|parking_aisle|driveway|private|emergency_access"](poly:"40.70680638521681 -74.02518380660537 40.70705848817867 -74.02512952793278 40.70721754156347 -74.02509141893525 40.70734561839358 -74.02505759983011 40.70740483091021 -74.02504355063066 40.70744929898526 -74.02503269654500 40.70779670366062 -74.02494552548363 40.70807803340058 -74.02486258702245 40.70810543388215 -74.02485328919660 40.70833025347751 -74.02476321844880 40.70839217885294 -74.02476018901599 40.70841307898511 -74.02475799084451 40.70896545579295 -74.02465432884482 40.70914239414800 -74.02460626664161 40.71069161083206 -74.02422328947414 40.71069987308685 -74.02422123644044 40.71101792525257 -74.02414180097216 40.71131489090750 -74.02406753564928 40.71181568954047 -74.02394292232316 40.71230586482102 -74.02384996705577 40.71297698925607 -74.02372816319236 40.71345037218835 -74.02364267871900 40.71357663546890 -74.02361118461991 40.71369660360418 -74.02359696009852 40.71424400913169 -74.02349770701427 40.71425925905061 -74.02349490702379 40.71555472447320 -74.02325407777592 40.71574676335555 -74.02321878610431 40.71923188461657 -74.02257872399223 40.71953066821878 -74.02251029604587 40.71955866862758 -74.02250259835245 40.71997836408129 -74.02235918554216 40.72013627465418 -74.02228326609406 40.72020678232310 -74.02229168680482 40.72065781347653 -74.02228601365574 40.72110615112074 -74.02222107537041 40.72145285513920 -74.02214760476213 40.72188483712986 -74.02202724196685 40.72230577518950 -74.02185185528619 40.72271162282746 -74.02162312970337 40.72309847854750 -74.02134326306435 40.72346262336298 -74.02101494498024 40.72356432252279 -74.02090250842781 40.72391787532813 -74.02064519938162 40.72427997782940 -74.02031723413430 40.72461602095211 -74.01994441392014 40.72492280090707 -74.01953029252742 40.72519739285686 -74.01907881766952 40.72525222293672 -74.01896802575577 40.72531743829303 -74.01906290333572 40.72563836961889 -74.01944775025586 40.72598601385503 -74.01979016983054 40.72635713721900 -74.02008697618416 40.72674828746885 -74.02033540759481 40.72715582600679 -74.02053315220552 40.72757596171773 -74.02067836955683 40.72800478622915 -74.02076970773928 40.72843831026402 -74.02080631600529 40.72887250074913 -74.02078785272154 40.72902780173987 -74.02077136631982 40.72947336943435 -74.02069449887559 40.72991089183139 -74.02055964536241 40.73033601303544 -74.02036814724026 40.73074450053529 -74.02012191001403 40.73092997229779 -74.01997913081783 40.73116473160003 -74.01994606880767 40.73159989172363 -74.01985630561998 40.73188600179250 -74.01975887034195 40.73221954465902 -74.01986412738599 40.73265528264990 -74.01994361592890 40.73309484104676 -74.01996684416898 40.73337314149279 -74.01996366883427 40.73381651304450 -74.01992982356414 40.73425519340825 -74.01983873800896 40.73468491704731 -74.01969129673228 40.73510150543655 -74.01948893235081 40.73550090770001 -74.01923361164316 40.73587924000979 -74.01892781645955 40.73623282336262 -74.01857451961727 40.73655821936697 -74.01817715601454 40.73685226369162 -74.01773958924365 40.73711209684960 -74.01726607402678 40.73727242551011 -74.01690325484530 40.73731040029919 -74.01691223272410 40.73733335752532 -74.01692838886048 40.73735685687267 -74.01694299035094 40.73777897958576 -74.01717163400833 40.73780866836786 -74.01718325607989 40.73816365012186 -74.01753782636057 40.73854731531824 -74.01784691961036 40.73895252427153 -74.01810414337281 40.73937523285461 -74.01830692949414 40.73981122220894 -74.01845325300543 40.74025614084296 -74.01854165237091 40.74070554805685 -74.01857124411771 40.74074624809842 -74.01857124772762 40.74117732573129 -74.0185441009565 ...
# INFO:osmnx:Downloaded 5,158.2KB from www.overpass-api.de in 7.02 seconds
# INFO:osmnx:Saved response to cache file "cache/0cee7dbd348d749faba40994fa857342.json"
# INFO:osmnx:Got all network data within polygon from API in 1 request(s) and 7.78 seconds
# INFO:osmnx:Creating networkx graph from downloaded OSM data...
# INFO:osmnx:Created graph with 21,278 nodes and 30,325 edges in 0.78 seconds
# C:\Users\richa\Anaconda3\lib\site-packages\pandas\core\computation\check.py:17: UserWarning: The installed version of numexpr 2.4.4 is not supported in pandas and will be not be used
# The minimum supported version is 2.4.6
#
#   ver=ver, min_ver=_MIN_NUMEXPR_VERSION), UserWarning)
# INFO:osmnx:Added edge lengths to graph in 0.62 seconds
# INFO:osmnx:Identifying all nodes that lie outside the polygon...
# INFO:osmnx:Created r-tree spatial index for 21,278 points in 1.22 seconds
# INFO:osmnx:Identified 20,657 nodes inside polygon in 1.15 seconds
# INFO:osmnx:Removed 621 nodes outside polygon in 0.00 seconds
# INFO:osmnx:Begin topologically simplifying the graph...
# INFO:osmnx:Identified 4,855 edge endpoints in 0.26 seconds
# INFO:osmnx:Constructed all paths to simplify in 0.04 seconds
# INFO:osmnx:Simplified graph (from 20,657 to 4,987 nodes and from 29,451 to 10,645 edges) in 1.46 seconds
# INFO:osmnx:Identifying all nodes that lie outside the polygon...
# INFO:osmnx:Created r-tree spatial index for 4,987 points in 0.25 seconds
# INFO:osmnx:Identified 4,626 nodes inside polygon in 0.61 seconds
# INFO:osmnx:Removed 361 nodes outside polygon in 0.00 seconds
# INFO:osmnx:Removed 0 isolated nodes
# INFO:osmnx:Graph was not connected, retained only the largest weakly connected component (4,468 of 4,626 total nodes) in 0.55 seconds
# INFO:osmnx:Got the counts of undirected street segments incident to each node (before removing peripheral edges) in 0.80 seconds
# INFO:osmnx:graph_from_polygon() returning graph with 4,468 nodes and 9,704 edges
# INFO:osmnx:graph_from_place() returning graph with 4,468 nodes and 9,704 edges

# %% [markdown]
# ### get rid of some double ways ###

# %%
accident_file = "collisions"
traveltime_file = "travel_times_2013_250000lines"

accidents_raw=pandas.read_pickle(accident_file+".p")
traveltimes_raw=pandas.read_pickle(traveltime_file+".p")

# %%
def simplify(in_Dict):
    return {"length": in_Dict[0]["length"]}

G=networkx.DiGraph()
temp=[(begin,end,simplify(G_raw[begin][end])) for (begin,end) in G_raw.edges(keys=False)]
G.add_edges_from(temp)

# %% [markdown]
# ### load accident file and include in graph ###

# %%
accidents=accidents_raw.copy()
accidents.set_index("node",drop=True,inplace=True)
accidents=accidents.groupby(level="node").size()
accidents.head()
# Out:
# node
# 42421728    12
# 42421731    12
# 42421737    38
# 42421741    21
# 42421749     9
# dtype: int64

# %%
networkx.set_edge_attributes(G,0,"accidents") #set default value of zero accidents
for node,count in accidents.iteritems():
    if node not in G.nodes: # discard if node is not in graph
        continue
    for begin,end in G.in_edges(node):
        G[begin][end]["accidents"]=count

# %% [markdown]
# ### load traveltimes and include in graph ###

# %%
traveltimes=pandas.DataFrame(traveltimes_raw)
traveltimes.set_index(["begin_node","end_node"],drop=True,inplace=True)
traveltimes.head()
# Out:
#                                datetime  travel_time
# begin_node end_node
# 42421728   42435337 2013-12-31 23:00:00      20.4412
#            42432736 2013-12-31 23:00:00      24.6495
#            42435337 2013-12-31 22:00:00      10.5158
#            42432736 2013-12-31 22:00:00      13.0787
#            42435337 2013-12-31 21:00:00      11.4267

# %%
traveltimes_means=traveltimes["travel_time"].groupby(
    level=["begin_node","end_node"]).mean()

networkx.set_edge_attributes(G,numpy.inf,"time") #set default value of infinite time. 
for edge,traveltime in traveltimes_means.items():
    if edge not in G.edges: # discard if edge is not in graph
        continue
    begin,end=edge
    G[begin][end]["time"]=traveltime

# %%
def makePath(origin_node,destination_node,alpha):
    for begin,end in G.edges:
        G[begin][end]["cost"]=(1-alpha)*G[begin][end]["time"]+alpha*G[begin][end]["accidents"]
        
    return networkx.shortest_path(G,source=origin_node,target=destination_node,weight="cost")

        
(origin,destination)=(42435654,42454325)
print(makePath(origin,destination,0.5))
# Out:
# [42435654, 42435657, 42439968, 42428277, 42428272, 42428268, 42428264, 42428258, 42430311, 42452973, 42434946, 42437644, 42446701, 42443680, 42451674, 42437686, 42427786, 42438544, 42434800, 42429874, 42453624, 449581627, 42428201, 42428198, 42428192, 42428183, 42428179, 42428174, 42428170, 42438785, 42431491, 42431490, 42430255, 42439826, 42435598, 387180916, 4557517550, 4557517554, 42454325]

# %% [markdown]
# ### test ###

# %%
(origin,destination)=(42438971, 42452956)
print(makePath(origin,destination,0.25))
print(" ")
print(makePath(origin,destination,0.75))
# Out:
# [42438971, 42443061, 42443058, 42443056, 42443054, 42434175, 42443052, 42443050, 42443048, 42443046, 42443044, 42436549, 42443042, 42443040, 42429340, 42443037, 42435516, 42443032, 42439406, 42443029, 42438506, 42438509, 42452956]
#
# [42438971, 42443061, 42443058, 42443056, 42443054, 42434175, 42443052, 42443050, 42443048, 42443046, 42443044, 42444820, 42428047, 42428045, 42428043, 42445757, 42451773, 42429348, 42451766, 42435522, 42448257, 42439416, 42451754, 42428024, 42452956]

# %% [markdown]
# ### for some (O,D) pairs, the quickest path is also accident-free ##

# %%
(origin,destination)=(42435654,42454325)
print(makePath(origin,destination,0.25))
print(" ")
print(makePath(origin,destination,0.75))
# Out:
# [42435654, 42435657, 42439968, 42439964, 42433611, 42428268, 42428264, 42428258, 42430311, 42452973, 42434946, 42437644, 42446701, 42443680, 42451674, 42437686, 42427786, 42438544, 42434800, 42429874, 42453624, 449581627, 42428201, 42428198, 42428192, 42428183, 42428179, 42428174, 42428170, 42438785, 42431491, 42431490, 42430255, 42439826, 42435598, 387180916, 4557517550, 4557517554, 42454325]
#
# [42435654, 42435657, 42439968, 42428277, 42428272, 42428268, 42428264, 42428258, 42430311, 42452973, 42434946, 42437644, 42446701, 42443680, 42451674, 42437686, 42427786, 42438544, 42434800, 42429874, 42453624, 449581627, 42428201, 42428198, 42428192, 42428183, 42428179, 42428174, 42428170, 42438785, 42431491, 42431490, 42430255, 42439826, 42435598, 387180916, 4557517550, 4557517554, 42454325]
